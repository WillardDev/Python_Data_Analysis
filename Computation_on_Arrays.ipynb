# %% [markdown]
# ## Computation on NumPy Arrays: Universal Functions

# %%
import numpy as np

# %%
x = np.array([2, 3, 4])
y = np.array([7, 8, 9])
# x + y
# Out:
# array([ 9, 11, 13])

# %%
xy = np.add(x, y)
xy
# Out:
# array([ 9, 11, 13])
