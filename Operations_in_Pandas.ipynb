# %% [markdown]
# # Operating on Data in Pandas

# %% [markdown]
# ## Ufuncs: Index Preservation

# %%
import pandas as pd
import numpy as np

# %%
np.random.seed(42)
ser = pd.Series(np.random.randint(1, 10, 4))
ser
# Out:
# 0    7
# 1    4
# 2    8
# 3    5
# dtype: int64
